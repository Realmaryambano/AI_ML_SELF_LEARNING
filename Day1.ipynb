# %% [markdown]
# <a href="https://colab.research.google.com/github/Realmaryambano/AI_ML_SELF_LEARNING/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello
